# %%
# Use the inbuilt dataset 'titanic' as used in the above problem.
# 1. Plot a box plot for distribution of age with respect to each gender along with the information
# about whether they survived or not. (Column names : 'sex' and 'age')
# 2. Write observations on the inference from the above statistics.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv(r"Dataset\Titanic-Dataset.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data["Age"].fillna(value = data["Age"].mean(), inplace = True)
data["Cabin"].fillna(value = "No_Cabin", inplace = True)
data["Embarked"].fillna(value = "N", inplace = True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
sns.histplot(data = data["Sex"], kde = True)
# Out:
# <Axes: xlabel='Sex', ylabel='Count'>

# %%
sns.histplot(data = data["Fare"], kde = True)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.histplot(data = data["Age"], kde = True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(data = data, x = "Sex", y = "Age", hue = "Survived")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(data = data, x = "Sex", y = "Survived")
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
sns.boxplot(data = data, x = "Sex", y = "Fare", hue = "Survived")
# Out:
# <Axes: xlabel='Sex', ylabel='Fare'>
